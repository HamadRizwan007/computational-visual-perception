# %%
# 1. Clone the repository
# !git clone https://github.com/prs-eth/Marigold.git
# %cd Marigold

# 2. Install dependencies (Using pip instead of Mamba for Colab)
# !pip install -r requirements.txt
# Out:
# Cloning into 'Marigold'...
# remote: Enumerating objects: 929, done.
# remote: Counting objects: 100% (475/475), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 929 (delta 373), reused 273 (delta 268), pack-reused 454 (from 1)
# Receiving objects: 100% (929/929), 9.71 MiB | 15.88 MiB/s, done.
# Resolving deltas: 100% (540/540), done.
# /content/Marigold
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.0/797.0 MB 817.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 120.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 82.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...

# %%
# !ls input/my_images
# Out:
# img.jpg

# %%
# !python script/depth/run.py \
    --checkpoint prs-eth/marigold-depth-v1-1 \
    --input_rgb_dir input/my_images \
    --output_dir output/my_results \
    --fp16
# Out:
# 2026-01-02 12:05:13.465793: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767355513.700615    8276 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767355513.767548    8276 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767355514.255819    8276 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
